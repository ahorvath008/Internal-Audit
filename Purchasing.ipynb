# %% [markdown]
# <a href="https://colab.research.google.com/github/ahorvath008/Internal-Audit/blob/main/Purchasing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import the file from Google Drive
file = ('/content/drive/MyDrive/Colab Notebooks/Trainline Purchasing.xlsx') 
df = pd.read_excel(file)
df.head(5)
# Out:
#   Purchase order Supplier account Invoice account              Supplier name  \
# 0  TTL-PO-013147    TTLSUP8103871   TTLSUP8103871     Jamie Tucker Media Ltd
# 1  TTL-PO-013146    TTLSUP8100016   TTLSUP8100016         Al Desco Foods Ltd
# 2  TTL-PO-013144    TTLSUP8100082   TTLSUP8100082            BUPA Healthcare
# 3  TTL-PO-013143    TTLSUP8100083   TTLSUP8100083                Bupa Dental
# 4  TTL-PO-013142    TTLSUP8101101   TTLSUP8101101  City of Edinburgh Council
#
#     Purchase type Approval status Purchase order status Currency  \
# 0  Purchase order        Approved            Open order      GBP
# 1  Purchase order       In review            Open order      GBP
# 2  Purchase order        Approved            Open order      GBP
# 3  Purchase order        Approved            Open order      GBP
# 4  Purchase order        Approved            Open order      GBP
#
#   Delivery date  Mode of delivery  Delivery terms Purchase agreement  \
# 0    2022-11-16               NaN             NaN                 No
# 1    2022-11-16               NaN             NaN                 No
# 2    2022-11-16               NaN             NaN                 No
# 3    2022-11-16               NaN             NaN                 No
# 4    2022-11-16               NaN             NaN                 No
#
#   Direct delivery
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
